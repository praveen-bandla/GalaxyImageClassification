# %%
#needed libraries for this notebook
import matplotlib.pylab as plt
# %matplotlib inline
import sys
import os

# %%
#giving asccess to the files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#adding the path to system to access models.py and utils.py
sys.path.append(os.path.abspath('/content/drive/MyDrive/156_Project/'))

# %%
#running the python scripts and importing all functions,models,classes
import models
import utils
from models import *
from utils import *

# %%
#hyperparameters: adjust as needed!
learning_rate = 1e-4
#if the optimizer isnt defined in the scripts, use keras.optimizers.(optimizer_name)
opt = Adam(lr=learning_rate)
#loss function
loss_func = 'mean_squared_error'
#currently the available ones are: VGG_16(), VGG_19(), CNN_implementation() (see models.py)
model = CNN_implementation()
#batch name
name = '9th2'
#desired length of dataset (max = 17,000)
sample_size = 5000
#training/test/validation splits
ratio = (80,10,10) 
#batch size for each step
size_of_batch = 32
#number of epochs
epochs = 50
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
#if it throws a path error, try re-running. Google colab sometimes times out!
hist = generate_model(model, opt,loss_func,name,sample_size,ratio,size_of_batch,epochs, generate_splits = False)
# Out:
# path: success!
# entries: success!
# Epoch 1/50
# /content/drive/MyDrive/156_Project/utils.py:421: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(BatchGenerator(fetcher),
# Epoch 1: val_loss improved from inf to 0.06217, saving model to tmp/weights.hdf5
# 30/30 - 4s - loss: 0.0832 - rmse: 0.2885 - val_loss: 0.0622 - val_rmse: 0.2493 - 4s/epoch - 121ms/step
# Epoch 2/50
#
# Epoch 2: val_loss improved from 0.06217 to 0.03954, saving model to tmp/weights.hdf5
# 30/30 - 1s - loss: 0.0514 - rmse: 0.2268 - val_loss: 0.0395 - val_rmse: 0.1988 - 947ms/epoch - 32ms/step
# Epoch 3/50
#
# Epoch 3: val_loss did not improve from 0.03954
# 30/30 - 0s - loss: 0.0629 - rmse: 0.2508 - val_loss: 0.0697 - val_rmse: 0.2640 - 275ms/epoch - 9ms/step
# Epoch 4/50
#
# Epoch 4: val_loss did not improve from 0.03954
# ...
